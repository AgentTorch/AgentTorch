# %%
import pandas as pd

# %%
demographic_file = '/Users/shashankkumar/Documents/AgentTorch_Official/AgentTorch/AgentTorch/helpers/census_data/nyc/nta/demo_2021acs5yr_nta.xlsx'
demo_df = pd.read_excel(demographic_file)

# %%
demo_df
# Out:
#      GeoType  NTAType                     GeogName   GeoID        Borough  \
# 0    NTA2020        0                   Greenpoint  BK0101       Brooklyn
# 1    NTA2020        0                 Williamsburg  BK0102       Brooklyn
# 2    NTA2020        0           South Williamsburg  BK0103       Brooklyn
# 3    NTA2020        0            East Williamsburg  BK0104       Brooklyn
# 4    NTA2020        0             Brooklyn Heights  BK0201       Brooklyn
# ..       ...      ...                          ...     ...            ...
# 257  NTA2020        9      Freshkills Park (North)  SI0291  Staten Island
# 258  NTA2020        9      Freshkills Park (South)  SI0391  Staten Island
# 259  NTA2020        9  Hoffman & Swinburne Islands  SI9591  Staten Island
# 260  NTA2020        9                 Miller Field  SI9592  Staten Island
# 261  NTA2020        9             Great Kills Park  SI9593  Staten Island
#
#      Pop_1E  Pop_1M  Pop_1C  Pop_1P  Pop_1Z  ...  AsnOAsnE  AsnOAsnM  \
# ...

# %%
list_of_boroughs = demo_df['Borough'].unique()

# %%
demo_df_b = []
for b in list_of_boroughs:
    demo_df_b.append(demo_df[demo_df['Borough'] == b])

# %%
for i in range(len(demo_df_b)):
    print(demo_df_b[i]['Pop_1E'].sum())
# Out:
# 2712360
# 1473354
# 1657374
# 2399765
# 493194
